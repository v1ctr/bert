# %%
import pandas as pd
import csv

# %%
dfcols = ['tweet', 
          'label_task_1', 
          'label_task_2'
         ]
#germeval_train = pd.read_csv("germeval2018.training.txt", sep="\t", header=None, names=dfcols)
germeval_test = pd.read_csv("germeval2018.test.txt", sep="\t", header=None, names=dfcols)
germeval_test
# Out:
#                                                   tweet label_task_1  \
# 0     Meine Mutter hat mir erzählt, dass mein Vater ...        OTHER
# 1     @Tom174_ @davidbest95 Meine Reaktion; |LBR| Ni...        OTHER
# 2     #Merkel rollt dem Emir von #Katar, der islamis...        OTHER
# 3     „Merle ist kein junges unschuldiges Mädchen“ K...        OTHER
# 4     @umweltundaktiv Asylantenflut bringt eben nur ...      OFFENSE
# 5     @_StultaMundi Die Bibel enthält ebenfalls Gese...        OTHER
# 6     @Thueringen_ @Miquwarchar @Pontifex_de Man mun...        OTHER
# 7     @hugresch @saltomentale Seit dem ist die Gesel...        OTHER
# 8     Wenn man Mädchen bildet, bildet man Generation...        OTHER
# 9     @FeePatzer Frauen zu einem "Ja" zu überreden, ...      OFFENSE
# 10    @IvyandWoe Ich weiß halt, wie man Frauen zum M...      OFFENSE
# 11     Liebe Freunde, Gauck,das Symbol des Sklaventums!      OFFENSE
# 12    @mountainman1977 @StapelChipsYT Au ja. Ich ste...        OTHER
# ...

# %%
len(germeval_test)
# Out:
# 3398

# %%
#germeval_train.to_csv("train.tsv", sep="\t")
germeval_test.to_csv("test.tsv", sep="\t")

# %%
germeval_test.iloc[3276]
# Out:
# tweet           @endlosfrei: Merkel bricht geltendes Gesetz - ...
# label_task_1                                                OTHER
# label_task_2                                                OTHER
# Name: 3276, dtype: object
